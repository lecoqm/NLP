# %% [markdown]
# # First exploration (Mathis)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import os
import re

# %%
candidate_info = pd.read_csv('data/archelect_search.csv', dtype=str)

# %%
text_extracted_1981 = pd.DataFrame(columns=['id', 'text'])
files = os.listdir('data/legislatives_1981')
for file in files:
    with open('data/legislatives_1981/' + file, encoding="utf-8") as f:
        text = f.read()
        text = re.sub(r'(?<=\w)-\s+(?=\w)', '', text)
    text_extracted_1981 = pd.concat([text_extracted_1981, pd.DataFrame([[file.replace('.txt', ''), text]], columns=['id','text'])])
text_extracted_1981 = pd.merge(text_extracted_1981, candidate_info, how='inner')
# text_extracted_1981.head()
text
# Out:
# "Sciences Po / fonds CEVIPOF\nFRONT INDÉPENDANTISTE\nÉLECTIONS LÉGISLATIVES DU 14 JUIN 1981\nKANAKS, TRAVAILLEURS,\nUn grand nombre d'entre-vous a voté François Mitterrand lors des récentes élections présidentielles pour condamner la politique de la droite. L'élection de François Mitterrand rend désormais les changements nécessaires, possibles. Ces changements nécessaires sont ceux qui découlent de la plateforme minimale commune du Front Indépendantiste, prolongement de la lutte politique menée jusque-là par chacune des formations politiques qui le compose. Ce sont ceux aussi exprimés dans les luttes et les revendications politiques, syndicale ou autres menées sur le Territoire ou à l'extérieur.\nPrésident du Comité de Soutien à François Mitterrand, le député Roch Pidjot est particulièrement qualifié pour lui exprimer notre volonté de changement, le Président de la République l'a fait lui-même savoir. Candidat aux élections législatives sur la 1ère circonscription (Côte Est, lles Loyauté) il est accompagné de François Burck candidat sur la 2e circonscription (Côte Ouest, Nouméa) déjà candidat de l'opposition aux précédentes élections législatives.\nCes changements ne sont pas réservés à une minorité, mais répondent aux aspirations de la majorité de la population : les Kanaks et les travailleurs. Les élections législatives leur donnent l'occasion de se manifester en apportant leurs suffrages à Roch Pidjot et François Burck.\nLe Front Indépendantiste\nPLATE-FORME MINIMALE COMMUNE DU FRONT INDÉPENDANTISTE\nLE FRONT INDÉPENDANTISTE GARANTIT ET PROTEGE LES DROITS DE L'HOMME\n1 FRONT POUR L'INDÉPENDANCE\na) Indépendance politique\nLe Kanak peuple «indigène», légitime a seul le droit à l'Indépendance ; ce droit lui est confisqué par le pouvoir colonial, il faut le reconquérir.\nLes travailleurs non Kanaks doivent participer au combat pour l'Indépendance, et ne peuvent être légitimés que dans ce combat.\nLe pouvoir politique sera exercé par le peuple.\nb) Indépendance économique\nLe pouvoir colonial a confisqué le patrimoine Kanak et l'exploite pour son profit.\nLe peuple doit reprendre son patrimoine et le gérer luimême : terres, mines, ressources naturelles, ressources maritimes, la «culture», les moyens de production etc ...\nc) Indépendance culturelle\nLe pouvoir colonial a ignoré la culture Kanake si ce n'est que pour l'utiliser pour mieux s'imposer (folklorisation). La culture est le signe d'un peuple, il doit rejeter les modèles qui lui sont imposés, créer et promouvoir ses propres modèles.\n2 FRONT ANTI-CAPITALISTE ET ANTI-IMPÉRIALISTE\nIl faut combattre les rapports sociaux de domination engendrés par le Système capitaliste pour les remplacer par des rapports égalitaires.\nIl faut combattre l'emprise des sociétés multinationales et les gouvernements qui les soutiennent pour favoriser les échanges économiques et culturels entre les peuples notamment entre ceux du Pacifique et constituer ensemble un front anti-impérialiste.\nLe peuple mettra en place des structures politiques et économiques qui lui permettront de déjouer toutes tentatives capitaliste et impérialiste de poursuivre l'exploitation de la Nouvelle-calédonie au détriment du peuple par l'intermédiaire d'un gouvernement néo-colonial.\n3 FRONT POUR LE DÉVELOPPEMENT\nLe développement doit être conduit en fonction d'objectifs élaborés et approuvés par le peuple, il doit rejeter tout plan de développement qui lui est imposé.\nLe Front Indépendantiste condamne le Plan Dijoud pour la bonne raison que le gouvernement français n'a pas à imposer ses objectifs aux Kanaks et aux autres travailleurs, et parce que\n· le Plan Dijoud est une nouvelle étape de la politique d'intégration économique, sociale et culturelle ;\n· il consolide les positions du capitalisme et des multinationales dans le Pacifique ;\n· il constitue la plate-forme des forces réactionnaires pour la défense des privilèges locaux.\n4 FRONT POUR LES TERRES KANAKES\nLa colonisation a volé les terres Kanakes, le Fro ...

# %%
text_extracted_1981 = text_extracted_1981[['id', 'text', 'date', 'contexte-election',
       'contexte-tour', 'cote', 'departement',
       'departement-insee', 'identifiant de circonscription', 'titulaire-sexe',
       'titulaire-profession', 'titulaire-mandat-en-cours',
       'titulaire-mandat-passe', 'titulaire-associations',
       'titulaire-autres-statuts', 'titulaire-soutien', 'titulaire-liste',
       'titulaire-decorations']]
text_extracted_1981.head()
# text_extracted_1981['title'].value_counts()
# Out:
#                                id  \
# 0  EL134_L_1981_06_001_01_1_PF_01
# 1  EL134_L_1981_06_001_01_1_PF_02
# 2  EL134_L_1981_06_001_01_1_PF_03
# 3  EL134_L_1981_06_001_01_1_PF_04
# 4  EL134_L_1981_06_001_01_1_PF_05
#
#                                                 text        date  \
# 0  ELECTIONS LEGISLATIVES - 14 JUIN 1981 AIN 1e C...  1981-06-14
# 1  Sciences Po / fonds CEVIPOF\nELECTIONS LÉGISLA...  1981-06-14
# 2  Sciences Po / fonds CEVIPOF\nRÉPUBLIQUE FRANÇA...  1981-06-14
# 3  REPUBLIQUE FRANÇAISE - ELECTIONS LEGISLATIVES ...  1981-06-14
# 4  REPUBLIQUE FRANÇAISE - PREMIERE CIRCONSCRIPTIO...  1981-06-14
#
#   contexte-election contexte-tour   cote departement departement-insee  \
# 0      législatives             1  EL134          01          01 - Ain
# 1      législatives             1  EL134          01          01 - Ain
# 2      législatives             1  EL134          01          01 - Ain
# 3      législatives             1  EL134          01          01 - Ain
# 4      législatives             1  EL134          01          01 - Ain
#
#   identifiant de circonscription titulaire-sexe     titulaire-profession  \
# 0                              1          femme       assistance sociale
# 1                              1          homme            non mentionné
# 2                              1          homme            non mentionné
# 3                              1          homme  conducteur poids lourds
# 4                              1          homme            non mentionné
#
#                       titulaire-mandat-en-cours titulaire-mandat-passe  \
# 0                                 maire-adjoint          non mentionné
# 1             maire-adjoint;conseiller régional          non mentionné
# 2                                 non mentionné          non mentionné
# 3                                 non mentionné          non mentionné
# 4  conseiller régional;maire;conseiller général                 député
#
#       titulaire-associations titulaire-autres-statuts  \
# 0              non mentionné            non mentionné
# 1                   syndicat            non mentionné
# 2        groupes de pression            non mentionné
# 3  socio-caritatif;politique                  réserve
# 4              non mentionné                  réserve
#
#                                    titulaire-soutien  \
# 0                            Parti socialiste unifié
# 1                          Parti communiste français
# 2  Parti socialiste;Mouvement des radicaux de gauche
# 3              Fédération des socialistes démocrates
# 4  Rassemblement pour la République;Union pour la...
#
#                    titulaire-liste titulaire-decorations
# 0                    non mentionné                   non
# 1               Union de la gauche                   non
# 2                    non mentionné                   non
# 3                    non mentionné                   non
# 4  Union pour la nouvelle majorité                   oui

# %%
mandats_uniques = (
    candidate_info["titulaire-mandat-en-cours"]
    .dropna()
    .str.split(";")
    .explode()
    .str.strip()
    .dropna()
    .unique()
)

mandats_uniques
# Out:
# array(['maire', 'conseiller général', 'non mentionné',
#        'conseiller municipal', 'adjoint au maire', 'adjoint de la ville',
#        'maire-adjoint', 'sénateur', 'haut commissaire',
#        'conseiller municipal délégué', 'ministre', 'maire délégué',
#        'maire rural', 'sénateur suppléant', 'sénateur remplaçant',
#        'député', "secrétaire d'Etat", 'adjoint spécial', 'adjoint-maire',
#        'conseiller municipal suppléant',
#        'Président de la République par intérim', 'conseiller régional',
#        'ministre délégué', 'député européen', 'élu local',
#        'adjoint de mairie', 'membre du parlement européen', 'adjoint',
#        'Président de la République', 'parlementaire européen',
#        'maire résident du conseil général', 'vice-maire-adjoint',
#        'élu municipal', 'conseilller régional', 'conseiller territorial',
#        'élu', 'premier ministre', "conseiller d'arrondissement",
#        'conseiller communautaire', "maire d'arrondissement",
#        'conseiller régional suppléant', 'élu départemental', 'députée',
#        'maire adjoint', 'sénatrice', 'députée européenne'], dtype=object)

# %%
mandats_uniques_1 = (
    candidate_info["titulaire-mandat-passe"]
    .dropna()
    .str.split(";")
    .explode()
    .str.strip()
    .dropna()
    .unique()
)

mandats_uniques_1
# Out:
# array(['non mentionné', 'député sortant', 'député', 'ministre',
#        'conseiller municipal', 'conseiller général', 'adjoint au maire',
#        "sous-secrétaire d'Etat", 'maire', 'Président du Conseil',
#        'sénateur', 'élu sortant', 'député invalidé', "secrétaire d'Etat",
#        'haut-commissaire', 'adjoint', 'maire-adjoint', 'sénateur  député',
#        'député honoraire', 'député suppléant',
#        'membre honoraire du Parlement',
#        "membre honoraire de l'Assemblée nationale",
#        'ministre hors classe', 'maire-adjoint honoraire',
#        'vice-président du Conseil', 'Président de la République',
#        'conseiller municipal délégué', 'maire honoraire',
#        'président du Conseil', 'adjoint spécial', 'Premier ministre',
#        'conseiller régional', 'député adjoint',
#        'conseiller général honoraire', 'élu municipal', 'député européen',
#        'conseiller régional sortant', 'premier ministre',
#        'sénateur suppléant', 'membre honoraire du parlement',
#        'député européen sortant', "maire d'arrondissement",
#        'maire sortant', "conseiller d'arrondissement",
#        'sénateur honoraire', 'maire adjoint',
#        'conseiller général sortant', 'députée'], dtype=object)

# %%
mandat_mapping = {
    'non mentionné': 0,

    'conseiller municipal': 1,
    'conseiller général': 1,
    'adjoint au maire': 1,
    'adjoint': 1,
    'maire-adjoint': 1,
    'député suppléant': 1,
    'maire-adjoint honoraire': 1,
    'conseiller municipal délégué': 1,
    'adjoint spécial': 1,
    'conseiller régional': 1,
    'député adjoint': 1,
    'conseiller général honoraire': 1,
    'élu municipal': 1,
    'conseiller régional sortant': 1,
    'sénateur suppléant': 1,
    "conseiller d'arrondissement": 1,
    'maire adjoint': 1,
    'conseiller général sortant': 1, 
    'élu sortant': 1,
    'conseiller régional suppléant': 1,
    'adjoint de mairie': 1,
    'conseiller municipal suppléant': 1,
    'élu': 1,
    'adjoint-maire': 1,
    'vice-maire-adjoint': 1,
    'sénateur remplaçant': 1,
    'conseiller communautaire': 1,
    'conseilller régional': 1,
    'conseiller territorial': 1,
    'adjoint de la ville': 1,
    'élu local': 1,
    'élu départemental': 1,
    'maire délégué': 1,

    'maire': 2,
    'maire honoraire': 2,
    "maire d'arrondissement": 2,
    'maire sortant': 2,
    'maire rural': 2,
    'maire résident du conseil général': 2,

    'sénateur': 2,
    'député européen': 2,
    'député européen sortant': 2,
    'sénateur honoraire': 2,
    'députée européenne': 2,
    'parlementaire européen': 2,
    'membre du parlement européen': 2,
    'sénatrice': 2,

    'député sortant': 3, 
    'député': 3,
    "sous-secrétaire d'Etat": 3,
    'député invalidé': 3,
    "secrétaire d'Etat": 3,
    'sénateur  député': 3,
    'député honoraire': 3,
    'membre honoraire du Parlement': 3,
    "membre honoraire de l'Assemblée nationale": 3,
    'membre honoraire du parlement': 3,
    'députée': 3,
    'ministre délégué': 3,

    'haut commissaire': 4,
    'Président de la République par intérim': 4,
    'ministre': 4,
    'Président du Conseil': 4,
    'haut-commissaire': 4,
    'ministre hors classe': 4,
    'vice-président du Conseil': 4,
    'Président de la République': 4,
    'président du Conseil': 4,
    'Premier ministre': 4,
    'premier ministre': 4,
    }

# %%
partis_uniques = (
    candidate_info["titulaire-soutien"]
    .dropna()
    .str.split(";")
    .explode()
    .str.strip()
    .dropna()
    .unique()
)

candidate_info['titulaire-soutien'].value_counts()
# Out:
# titulaire-soutien
# non mentionné                                                       6223
# Parti communiste français                                           4602
# Parti socialiste                                                    1823
# Front national                                                      1386
# Lutte ouvrière                                                      1076
#                                                                     ...
# Nous citoyens;Européens solidaires;Union des mouvements citoyens       1
# Union de la gauche socialiste                                          1
# Indépendants et paysans;Démocrates chrétiens;Centre républicain        1
# centre;Indépendants et paysans                                         1
# Républicains sociaux;Union pour la nouvelle République                 1
# Name: count, Length: 2927, dtype: int64
